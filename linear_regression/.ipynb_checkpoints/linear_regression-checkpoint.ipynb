# %% [markdown]
# ## Simple Linear Regression Algorithm

# %%
import numpy as np
import random

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# ## Produce target and response data

# %%
X = np.linspace(1,20,20)

# true function
y_true = 2*X + 5

# function with 'error term'
y_rand = 2*X + 5 + np.random.randint(-10, 10, len(X))

# %%
plt.scatter(X, y_rand, color = 'r', s = 20) 
plt.plot(X, y_true, color='m')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## OLS

# %%
def simple_ols(X, y):
    X_bar = np.mean(X)
    y_bar = np.mean(y)
    
    num_list   = [(X[i] - X_bar) * (y[i] - y_bar) for i in range(len(X))]
    denom_list = [(X[i] - X_bar)**2 for i in range(len(X))]
    
    # slope
    b1 = sum(num_list)/sum(denom_list)
    
    # intercept
    b0 = y_bar - b1*X_bar
    
    return b0, b1

# %%
b0, b1 = simple_ols(X, y_rand)
print('slope: ', b1)
print('intercept: ', b0)
# Out:
# slope:  2.184962406015038
# intercept:  3.857894736842102

# %%
y_est = b1*X + b0

# %%
plt.scatter(X, y_rand, color = 'r', s = 20) 
plt.plot(X, y_true, color='m')
plt.plot(X, y_est, color='g')
plt.xlabel('X')
plt.ylabel('y')
plt.show()
